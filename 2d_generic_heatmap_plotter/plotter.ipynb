# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("./3.csv", index_col = 0)
df
# Out:
#             3
# 0  -49.323529
# 1  -49.454545
# 2  -49.884615
# 3  -47.176471
# 4  -45.906977
# 5  -45.000000
# 6  -44.781250
# 7  -45.655172
# 8  -44.666667
# 9  -44.437500
# 10 -43.857143
# 11 -42.935484
# 12 -43.000000
# 13 -43.000000
# 14 -43.166667
# 15 -43.821429
# 16 -46.538462

# %% [markdown]
# # Tag1

# %%
plt.figure(figsize=(1,10))

sns.set_context('paper', font_scale=1.4)
sns.heatmap(df, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # tag 2

# %%
df = pd.read_csv("./tag2/tag2.csv", delimiter='\t', index_col = 0)
sns.set_context('paper', font_scale=1.4)
sns.heatmap(df, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # tag 3

# %%
df = pd.read_csv("./tag3/tag3.csv", delimiter='\t', index_col = 0)
sns.set_context('paper', font_scale=1.4)
sns.heatmap(df, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("./tag4/tag4.csv", delimiter='\t', index_col = 0)
sns.set_context('paper', font_scale=1.4)
sns.heatmap(df, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>
